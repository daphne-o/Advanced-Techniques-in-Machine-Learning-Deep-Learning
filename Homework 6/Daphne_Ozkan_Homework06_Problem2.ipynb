# %% [markdown]
# ### Question 1

# %%
# !pip install bayesian-optimization==1.4.3
# Out:
# Requirement already satisfied: bayesian-optimization==1.4.3 in /venv/main/lib/python3.12/site-packages (1.4.3)
# Requirement already satisfied: numpy>=1.9.0 in /venv/main/lib/python3.12/site-packages (from bayesian-optimization==1.4.3) (2.1.2)
# Requirement already satisfied: scipy>=1.0.0 in /venv/main/lib/python3.12/site-packages (from bayesian-optimization==1.4.3) (1.15.3)
# Requirement already satisfied: scikit-learn>=0.18.0 in /venv/main/lib/python3.12/site-packages (from bayesian-optimization==1.4.3) (1.6.1)
# Requirement already satisfied: colorama>=0.4.6 in /venv/main/lib/python3.12/site-packages (from bayesian-optimization==1.4.3) (0.4.6)
# Requirement already satisfied: joblib>=1.2.0 in /venv/main/lib/python3.12/site-packages (from scikit-learn>=0.18.0->bayesian-optimization==1.4.3) (1.5.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /venv/main/lib/python3.12/site-packages (from scikit-learn>=0.18.0->bayesian-optimization==1.4.3) (3.6.0)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms
from ray import tune
from ray.tune.search.bayesopt import BayesOptSearch
from ray.tune.schedulers import HyperBandScheduler
import time

# %%
class LeNet(nn.Module):
    def __init__(self, conv_filters, hidden, dropout):
        super(LeNet, self).__init__()
        conv_filters = max(8, int(conv_filters) // 8 * 8)
        hidden = int(hidden)
        self.conv1 = nn.Conv2d(1, conv_filters, kernel_size=5)
        self.conv2 = nn.Conv2d(conv_filters, 32, kernel_size=5)
        self.fc1 = nn.Linear(512, hidden)
        self.fc2 = nn.Linear(hidden, 10)
        self.dropout = nn.Dropout(float(dropout))

    def forward(self, x):
        x = F.relu(F.max_pool2d(self.conv1(x), 2))
        x = F.relu(F.max_pool2d(self.conv2(x), 2))
        x = x.view(-1, 512)
        x = self.dropout(F.relu(self.fc1(x)))
        return self.fc2(x)

# %%
from ray.air import session

def train_mnist(config):
    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = LeNet(config["conv_filters"], config["hidden"], config["dropout"]).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=config["lr"])

    transform = transforms.Compose([transforms.ToTensor()])
    train_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST(root="~/data", train=True, download=True, transform=transform),
        batch_size=int(config["batch_size"]), shuffle=True)
    test_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST(root="~/data", train=False, download=True, transform=transform),
        batch_size=256, shuffle=False)

    for epoch in range(3):
        model.train()
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            optimizer.zero_grad()
            loss = F.cross_entropy(model(batch_x), batch_y)
            loss.backward()
            optimizer.step()

    model.eval()
    correct, total = 0, 0
    with torch.no_grad():
        for batch_x, batch_y in test_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            output = model(batch_x)
            _, predicted = torch.max(output, 1)
            correct += (predicted == batch_y).sum().item()
            total += batch_y.size(0)
    session.report({"mean_accuracy": correct / total})

# %%
search_space_grid = {
    "conv_filters": tune.grid_search([64, 128, 256]),
    "lr": tune.grid_search([0.001, 0.01, 0.1]),
    "batch_size": tune.grid_search([64, 128, 256]),
    "dropout": tune.grid_search([0.0, 0.25, 0.5]),
    "hidden": tune.grid_search([128, 256, 512])
}

start = time.time()
grid_result = tune.run(
    train_mnist,
    config=search_space_grid,
    metric="mean_accuracy",
    mode="max",
    resources_per_trial={"gpu": 1}
)
end = time.time()

best_grid = grid_result.get_best_result(metric="mean_accuracy", mode="max")
print("Grid Search Best Config:", best_grid.config)
print("Grid Search Best Accuracy:", best_grid.metrics["mean_accuracy"])
print("Grid Search Time:", end - start)
# Out:
# 2025-05-13 07:47:45,834	WARNING utils.py:594 -- Detecting docker specified CPUs. In previous versions of Ray, CPU detection in containers was incorrect. Please ensure that Ray has enough CPUs allocated. As a temporary workaround to revert to the prior behavior, set `RAY_USE_MULTIPROCESSING_CPU_COUNT=1` as an env var before starting Ray. Set the env var: `RAY_DISABLE_DOCKER_CPU_WARNING=1` to mute this warning.
# 2025-05-13 07:47:45,835	WARNING utils.py:606 -- Ray currently does not support initializing Ray with fractional cpus. Your num_cpus will be truncated from 15.36 to 15.
# 2025-05-13 07:47:45,914	INFO worker.py:1888 -- Started a local Ray instance.
# 2025-05-13 07:47:46,319	INFO tune.py:253 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2025-05-13 07:47:46,320	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-05-13 08:29:18</td></tr>
# <tr><td>Running for: </td><td>00:41:32.57        </td></tr>
# <tr><td>Memory:      </td><td>43.9/250.9 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/15 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc              </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  conv_filters</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">  hidden</th><th style="text-align: right;">   lr</th><th style="text-align: right;">   acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_8f5a1_00000</td><td>TERMINATED</td><td>172.17.0.2:93499 </td><td style="text-align: right;">          64</td><td style="text-align: right;">            64</td><td style="text-align: right;">     0   </td><td style="text-align: right;">     128</td><td style="text-align: right;">0.001</td><td style="text-align: right;">0.9884</td><td style="text-align: right;">     1</td><td style="text-align: right;">         8.66418</td></tr>
# <tr><td>train_mnist_8f5a1_00076</td><td style="text-align: right;">         0.992 </td></tr>
# <tr><td>train_mnist_8f5a1_00077</td><td style="text-align: right;">         0.9911</td></tr>
# <tr><td>train_mnist_8f5a1_00078</td><td style="text-align: right;">         0.9898</td></tr>
# <tr><td>train_mnist_8f5a1_00079</td><td style="text-align: right;">         0.9917</td></tr>
# <tr><td>train_mnist_8f5a1_00080</td><td style="text-align: right;">         0.988 </td></tr>
# <tr><td>train_mnist_8f5a1_00081</td><td style="text-align: right;">         0.9793</td></tr>
# <tr><td>train_mnist_8f5a1_00082</td><td style="text-align: right;">         0.9805</td></tr>
# <tr><td>train_mnist_8f5a1_00083</td><td style="text-align: right;">         0.9812</td></tr>
# <tr><t
# (train_mnist pid=93499) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=93499)   _log_deprecation_warning(
# (train_mnist pid=93639) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=93639)   _log_deprecation_warning(
# (train_mnist pid=93733) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=93733)   _log_deprecation_warning(
# (train_mnist pid=93823) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=93823)   _log_deprecation_warning(
# (train_mnist pid=93913) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=93913)   _log_deprecation_warning(
# (train_mnist pid=94006) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94006)   _log_deprecation_warning(
# (train_mnist pid=94097) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94097)   _log_deprecation_warning(
# (train_mnist pid=94188) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94188)   _log_deprecation_warning(
# (train_mnist pid=94278) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94278)   _log_deprecation_warning(
# (train_mnist pid=94366) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94366)   _log_deprecation_warning(
# (train_mnist pid=94462) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94462)   _log_deprecation_warning(
# (train_mnist pid=94552) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94552)   _log_deprecation_warning(
# (train_mnist pid=94640) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94640)   _log_deprecation_warning(
# (train_mnist pid=94737) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94737)   _log_deprecation_warning(
# (train_mnist pid=94827) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94827)   _log_deprecation_warning(
# (train_mnist pid=94916) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=94916)   _log_deprecation_warning(
# (train_mnist pid=95010) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95010)   _log_deprecation_warning(
# (train_mnist pid=95100) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95100)   _log_deprecation_warning(
# (train_mnist pid=95189) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95189)   _log_deprecation_warning(
# (train_mnist pid=95280) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95280)   _log_deprecation_warning(
# (train_mnist pid=95370) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95370)   _log_deprecation_warning(
# (train_mnist pid=95459) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95459)   _log_deprecation_warning(
# (train_mnist pid=95553) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95553)   _log_deprecation_warning(
# (train_mnist pid=95642) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95642)   _log_deprecation_warning(
# (train_mnist pid=95732) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95732)   _log_deprecation_warning(
# (train_mnist pid=95829) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95829)   _log_deprecation_warning(
# (train_mnist pid=95918) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=95918)   _log_deprecation_warning(
# (train_mnist pid=96008) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96008)   _log_deprecation_warning(
# (train_mnist pid=96101) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96101)   _log_deprecation_warning(
# (train_mnist pid=96191) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96191)   _log_deprecation_warning(
# (train_mnist pid=96280) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96280)   _log_deprecation_warning(
# (train_mnist pid=96371) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96371)   _log_deprecation_warning(
# (train_mnist pid=96461) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96461)   _log_deprecation_warning(
# (train_mnist pid=96550) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96550)   _log_deprecation_warning(
# (train_mnist pid=96644) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96644)   _log_deprecation_warning(
# (train_mnist pid=96733) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96733)   _log_deprecation_warning(
# (train_mnist pid=96823) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96823)   _log_deprecation_warning(
# (train_mnist pid=96919) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=96919)   _log_deprecation_warning(
# (train_mnist pid=97009) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97009)   _log_deprecation_warning(
# (train_mnist pid=97097) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97097)   _log_deprecation_warning(
# (train_mnist pid=97192) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97192)   _log_deprecation_warning(
# (train_mnist pid=97282) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97282)   _log_deprecation_warning(
# (train_mnist pid=97371) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97371)   _log_deprecation_warning(
# (train_mnist pid=97463) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97463)   _log_deprecation_warning(
# (train_mnist pid=97553) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97553)   _log_deprecation_warning(
# (train_mnist pid=97644) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97644)   _log_deprecation_warning(
# (train_mnist pid=97736) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97736)   _log_deprecation_warning(
# (train_mnist pid=97826) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97826)   _log_deprecation_warning(
# (train_mnist pid=97920) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=97920)   _log_deprecation_warning(
# (train_mnist pid=98011) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98011)   _log_deprecation_warning(
# (train_mnist pid=98101) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98101)   _log_deprecation_warning(
# (train_mnist pid=98193) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98193)   _log_deprecation_warning(
# (train_mnist pid=98284) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98284)   _log_deprecation_warning(
# (train_mnist pid=98373) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98373)   _log_deprecation_warning(
# (train_mnist pid=98463) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98463)   _log_deprecation_warning(
# (train_mnist pid=98553) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98553)   _log_deprecation_warning(
# (train_mnist pid=98643) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98643)   _log_deprecation_warning(
# (train_mnist pid=98735) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98735)   _log_deprecation_warning(
# (train_mnist pid=98826) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98826)   _log_deprecation_warning(
# (train_mnist pid=98916) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=98916)   _log_deprecation_warning(
# (train_mnist pid=99010) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99010)   _log_deprecation_warning(
# (train_mnist pid=99101) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99101)   _log_deprecation_warning(
# (train_mnist pid=99191) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99191)   _log_deprecation_warning(
# (train_mnist pid=99283) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99283)   _log_deprecation_warning(
# (train_mnist pid=99374) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99374)   _log_deprecation_warning(
# (train_mnist pid=99463) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99463)   _log_deprecation_warning(
# (train_mnist pid=99553) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99553)   _log_deprecation_warning(
# (train_mnist pid=99643) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99643)   _log_deprecation_warning(
# (train_mnist pid=99733) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99733)   _log_deprecation_warning(
# (train_mnist pid=99825) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99825)   _log_deprecation_warning(
# (train_mnist pid=99916) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=99916)   _log_deprecation_warning(
# (train_mnist pid=100006) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=100006)   _log_deprecation_warning(
# (train_mnist pid=100120) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=100120)   _log_deprecation_warning(
# (train_mnist pid=100211) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=100211)   _log_deprecation_warning(
# (train_mnist pid=100304) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=100304)   _log_deprecation_warning(
# (train_mnist pid=100393) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=100393)   _log_deprecation_warning(
# (train_mnist pid=100485) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=100485)   _log_deprecation_warning(
# ...
# (train_mnist pid=117993)   _log_deprecation_warning(
# (train_mnist pid=118087) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118087)   _log_deprecation_warning(
# (train_mnist pid=118177) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118177)   _log_deprecation_warning(
# (train_mnist pid=118266) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118266)   _log_deprecation_warning(
# (train_mnist pid=118357) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118357)   _log_deprecation_warning(
# (train_mnist pid=118447) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118447)   _log_deprecation_warning(
# (train_mnist pid=118540) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118540)   _log_deprecation_warning(
# (train_mnist pid=118629) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118629)   _log_deprecation_warning(
# (train_mnist pid=118721) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118721)   _log_deprecation_warning(
# (train_mnist pid=118811) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118811)   _log_deprecation_warning(
# (train_mnist pid=118901) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118901)   _log_deprecation_warning(
# (train_mnist pid=118997) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=118997)   _log_deprecation_warning(
# (train_mnist pid=119091) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119091)   _log_deprecation_warning(
# (train_mnist pid=119181) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119181)   _log_deprecation_warning(
# (train_mnist pid=119271) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119271)   _log_deprecation_warning(
# (train_mnist pid=119362) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119362)   _log_deprecation_warning(
# (train_mnist pid=119451) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119451)   _log_deprecation_warning(
# (train_mnist pid=119543) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119543)   _log_deprecation_warning(
# (train_mnist pid=119636) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119636)   _log_deprecation_warning(
# (train_mnist pid=119726) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=119726)   _log_deprecation_warning(
# (train_mnist pid=120007) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120007)   _log_deprecation_warning(
# (train_mnist pid=120100) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120100)   _log_deprecation_warning(
# (train_mnist pid=120191) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120191)   _log_deprecation_warning(
# (train_mnist pid=120281) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120281)   _log_deprecation_warning(
# (train_mnist pid=120371) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120371)   _log_deprecation_warning(
# (train_mnist pid=120463) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120463)   _log_deprecation_warning(
# (train_mnist pid=120553) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120553)   _log_deprecation_warning(
# (train_mnist pid=120643) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120643)   _log_deprecation_warning(
# (train_mnist pid=120733) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120733)   _log_deprecation_warning(
# (train_mnist pid=120829) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120829)   _log_deprecation_warning(
# (train_mnist pid=120919) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=120919)   _log_deprecation_warning(
# (train_mnist pid=121012) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121012)   _log_deprecation_warning(
# (train_mnist pid=121102) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121102)   _log_deprecation_warning(
# (train_mnist pid=121192) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121192)   _log_deprecation_warning(
# (train_mnist pid=121282) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121282)   _log_deprecation_warning(
# (train_mnist pid=121372) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121372)   _log_deprecation_warning(
# (train_mnist pid=121465) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121465)   _log_deprecation_warning(
# (train_mnist pid=121555) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121555)   _log_deprecation_warning(
# (train_mnist pid=121645) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121645)   _log_deprecation_warning(
# (train_mnist pid=121757) /venv/main/lib/python3.12/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (train_mnist pid=121757)   _log_deprecation_warning(

# %%
end = time.time()

best_grid = grid_result.get_best_trial(metric="mean_accuracy", mode="max", scope="all")

if best_grid is not None:
    print("Grid Search Best Config:", best_grid.config)
    print("Grid Search Best Accuracy:", best_grid.last_result["mean_accuracy"])
else:
    print("No successful trials found in grid search.")

print("Grid Search Time: {:.2f} seconds".format(end - start))
# Out:
# Grid Search Best Config: {'conv_filters': 128, 'lr': 0.001, 'batch_size': 64, 'dropout': 0.5, 'hidden': 512}
# Grid Search Best Accuracy: 0.9932
# Grid Search Time: 2669.82 seconds

# %%
from ray import tune
from ray.air import session
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
from torchvision import transforms

def train_mnist(config):
    batch_size = int(config["batch_size"])
    conv_filters = int(config["conv_filters"])
    hidden = int(config["hidden"])
    dropout = float(config["dropout"])
    lr = float(config["lr"])

    class LeNet(nn.Module):
        def __init__(self):
            super(LeNet, self).__init__()
            conv_filters_rounded = max(8, conv_filters // 8 * 8)
            self.conv1 = nn.Conv2d(1, conv_filters_rounded, kernel_size=5)
            self.conv2 = nn.Conv2d(conv_filters_rounded, 32, kernel_size=5)
            self.fc1 = nn.Linear(512, hidden)
            self.fc2 = nn.Linear(hidden, 10)
            self.dropout = nn.Dropout(dropout)

        def forward(self, x):
            x = F.relu(F.max_pool2d(self.conv1(x), 2))
            x = F.relu(F.max_pool2d(self.conv2(x), 2))
            x = x.view(-1, 512)
            x = self.dropout(F.relu(self.fc1(x)))
            return self.fc2(x)

    device = "cuda" if torch.cuda.is_available() else "cpu"
    model = LeNet().to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    transform = transforms.Compose([transforms.ToTensor()])
    train_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST(
            root="~/data", train=True, download=True, transform=transform),
        batch_size=batch_size, shuffle=True)

    test_loader = torch.utils.data.DataLoader(
        torchvision.datasets.MNIST(
            root="~/data", train=False, download=True, transform=transform),
        batch_size=256, shuffle=False)

    for epoch in range(3): 
        model.train()
        for batch_x, batch_y in train_loader:
            batch_x, batch_y = batch_x.to(device), batch_y.to(device)
            optimizer.zero_grad()
            loss = F.cross_entropy(model(batch_x), batch_y)
            loss.backward()
            optimizer.step()

        model.eval()
        correct = 0
        total = 0
        with torch.no_grad():
            for batch_x, batch_y in test_loader:
                batch_x, batch_y = batch_x.to(device), batch_y.to(device)
                outputs = model(batch_x)
                _, predicted = torch.max(outputs, 1)
                total += batch_y.size(0)
                correct += (predicted == batch_y).sum().item()

        accuracy = correct / total
        session.report({"mean_accuracy": accuracy, "training_iteration": epoch + 1})

# %%
search_space_bayes = {
    "conv_filters": tune.uniform(64, 256),
    "lr": tune.loguniform(0.001, 0.1),
    "batch_size": tune.quniform(64, 256, 1),  
    "dropout": tune.uniform(0.0, 1.0),
    "hidden": tune.quniform(128, 512, 1)
}

bayes_search = BayesOptSearch(metric="mean_accuracy", mode="max")
start = time.time()
bayes_result = tune.run(
    train_mnist,
    config=search_space_bayes,
    search_alg=bayes_search,
    metric="mean_accuracy",
    mode="max",
    num_samples=20,
    resources_per_trial={"gpu": 1}
)
end = time.time()

best_bayes = bayes_result.get_best_result(metric="mean_accuracy", mode="max")
print("Bayesian Search Best Config:", best_bayes.config)
print("Bayesian Search Best Accuracy:", best_bayes.metrics["mean_accuracy"])
print("Bayesian Search Time:", end - start)
# Out:
# 2025-05-13 08:37:18,483	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2025-05-13 08:37:18,490	WARNING bayesopt_search.py:431 -- BayesOpt does not support specific sampling methods. The LogUniform sampler will be dropped.
# 2025-05-13 08:37:18,490	WARNING bayesopt_search.py:421 -- BayesOpt search does not support quantization. Dropped quantization.
# 2025-05-13 08:37:18,490	WARNING bayesopt_search.py:431 -- BayesOpt does not support specific sampling methods. The Uniform sampler will be dropped.
# 2025-05-13 08:37:18,490	WARNING bayesopt_search.py:421 -- BayesOpt search does not support quantization. Dropped quantization.
# 2025-05-13 08:37:18,490	WARNING bayesopt_search.py:431 -- BayesOpt does not support specific sampling methods. The Uniform sampler will be dropped.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-05-13 08:40:52</td></tr>
# <tr><td>Running for: </td><td>00:03:33.66        </td></tr>
# <tr><td>Memory:      </td><td>43.9/250.9 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 0/15 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name          </th><th>status    </th><th>loc              </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  conv_filters</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">  hidden</th><th style="text-align: right;">        lr</th><th style="text-align: right;">   acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</
# <tr><td>train_mnist_549e56c3</td><td style="text-align: right;">         0.1009</td></tr>
# <tr><td>train_mnist_5b44841a</td><td style="text-align: right;">         0.9604</td></tr>
# <tr><td>train_mnist_619a9d81</td><td style="text-align: right;">         0.1135</td></tr>
# <tr><td>train_mnist_7bb347e0</td><td style="text-align: right;">         0.1135</td></tr>
# <tr><td>train_mnist_7d8c3f18</td><td style="text-align: right;">         0.9759</td></tr>
# <tr><td>train_mnist_936b3c8a</td><td style="text-align: right;">         0.1135</td></tr>
# <tr><td>train_mnist_9b447c0c</td><td style="text-align: right;">         0.9879</td></tr>
# <tr><td>train_mnist_ad3946aa</td><td style="text-align: right;">         0.1028</td></tr>
# <tr><td>train_mnist_b345f7c4</td><td style="text-align: right;">         0.1135</td></tr>
# <tr><td>train_mnist_bb543eab</td><td style="text-align: right;">         0.9485</td></tr>
# <tr><td>train_mnist_d15eb5bd</td><td style="text-align: right;">         0.1135</td></tr>
# <tr><td>train_mnist_d21828f4</td><td style="text-align: right;">         0.1028</td></tr>
# <tr><td>train_mnist_de282bfb</td><td style="text-align: right;">         0.1135</td></tr>
# <tr><td>train_mnist_e1e54752</td><td style="text-align: right;">         0.874 </td></tr>
# <tr><td>train_mnist_e92d9fe8</td><td style="text-align: right;">         0.976 </td></tr>
# <tr><td>train_mnist_f84d82ba</td><td style="text-align: right;">         0.1135</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2025-05-13 08:40:52,154	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_mnist_2025-05-13_08-37-18' in 0.0053s.
# 2025-05-13 08:40:52,159	INFO tune.py:1041 -- Total run time: 213.68 seconds (213.66 seconds for the tuning loop).
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 22
#      11 bayes_result = tune.run(
#      12     train_mnist,
#      13     config=search_space_bayes,
#    (...)     18     resources_per_trial={"gpu": 1}
#      19 )
#      20 end = time.time()
# ---> 22 best_bayes = bayes_result.get_best_result(metric="mean_accuracy", mode="max")
#      23 print("Bayesian Search Best Config:", best_bayes.config)
#      24 print("Bayesian Search Best Accuracy:", best_bayes.metrics["mean_accuracy"])
#
# AttributeError: 'ExperimentAnalysis' object has no attribute 'get_best_result'

# %%
end = time.time()

best_bayes = bayes_result.get_best_trial(metric="mean_accuracy", mode="max", scope="all")

if best_bayes is not None:
    print("Bayesian Search Best Config:", best_bayes.config)
    print("Bayesian Search Best Accuracy:", best_bayes.last_result["mean_accuracy"])
else:
    print("No successful trials found in Bayesian search.")

print("Bayesian Search Time: {:.2f} seconds".format(end - start))
# Out:
# Bayesian Search Best Config: {'conv_filters': np.float64(102.33736617440508), 'lr': np.float64(0.005598590859279775), 'batch_size': np.float64(214.7537845874586), 'dropout': np.float64(0.5142344384136116), 'hidden': np.float64(355.4871944430243)}
# Bayesian Search Best Accuracy: 0.9879
# Bayesian Search Time: 516.04 seconds

# %%
search_space_hyperband = {
    "conv_filters": tune.randint(64, 257),
    "lr": tune.uniform(0.001, 0.1),
    "batch_size": tune.choice([64, 128, 256]),
    "dropout": tune.uniform(0.0, 1.0),
    "hidden": tune.randint(128, 513)
}

hyperband_scheduler = HyperBandScheduler(metric="mean_accuracy", mode="max")
start = time.time()

hyperband_result = tune.run(
    train_mnist,
    config=search_space_hyperband,
    scheduler=hyperband_scheduler,
    num_samples=20,
    resources_per_trial={"gpu": 1}
)
end = time.time()
# Out:
# 2025-05-13 08:56:41,779	INFO tune.py:616 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-05-13 09:00:13</td></tr>
# <tr><td>Running for: </td><td>00:03:31.86        </td></tr>
# <tr><td>Memory:      </td><td>43.6/250.9 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using HyperBand: num_stopped=0 total_brackets=3<br>Round #0:<br>  Bracket(Max Size (n)=5, Milestone (r)=81, completed=100.0%): {TERMINATED: 5} <br>  Bracket(Max Size (n)=3, Milestone (r)=81, completed=100.0%): {TERMINATED: 8} <br>  Bracket(Max Size (n)=5, Milestone (r)=27, completed=5.1%): {TERMINATED: 7} <br>Logical resource usage: 0/15 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status    </th><th>loc              </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  conv_filters</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">  hidden</th><th style="text-align: right;">       lr</th><th style="text-align: right;">   acc</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th></tr>
# </thead>
# <tbody>
# <tr><td>train_mnist_30465_00000</td><td>TERMINATED</td><td>172.17.0.2:120007</td><td style="text-align: right;">          64</td><td style="text-align: right;">           127</td><td style="text-align: right;">0.617635 </td><td style="text-align: right;">     256</td><td style="text-align: right;">0.0691736</td><td style="text-align: right;">0.0958</td><td style="text-align: right;">     3</td><td style="text-align: right;">         9.20293</td></tr>
# <tr><td>train_mnist_30465_00001</td><td>TERMINATED</td><td>172.17.0.2:120100</td><td style="text-align: right;">          64</td><td style="text-align: right;">           241</td><td style="text-align: right;">0.168519 </td><td style="text-align: right;">     441</td><td style="text-align: right;">0.0220862</td><td style="text-align: right;">0.9634</td><td style="text-align: right;">     3</td><td style="text-align: right;">         9.61084</td></tr>
# <tr><td>train_mnist_30465_00019</td><td style="text-align: right;">         0.9691</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# 2025-05-13 09:00:13,650	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/root/ray_results/train_mnist_2025-05-13_08-56-41' in 0.0052s.
# 2025-05-13 09:00:13,654	INFO tune.py:1041 -- Total run time: 211.87 seconds (211.86 seconds for the tuning loop).

# %%
best_hyper = hyperband_result.get_best_trial(metric="mean_accuracy", mode="max", scope="all")

if best_hyper is not None:
    print("Hyperband Best Config:", best_hyper.config)
    print("Hyperband Best Accuracy:", best_hyper.last_result["mean_accuracy"])
else:
    print("No successful trials found in Hyperband search.")

print("Hyperband Search Time: {:.2f} seconds".format(end - start))
# Out:
# Hyperband Best Config: {'conv_filters': 147, 'lr': 0.011312976753809767, 'batch_size': 256, 'dropout': 0.6772220821054592, 'hidden': 370}
# Hyperband Best Accuracy: 0.9814
# Hyperband Search Time: 211.88 seconds

# %% [markdown]
# ### Question 2

# %% [markdown]
# After performing Grid Search, Bayesian Search, and Hyperband for the given hyperparameter configurations, these were my results (copy-pasted from the printed outputs above so you can see the results for all 3 search methods together):
#
# Grid Search Best Config: {'conv_filters': 128, 'lr': 0.001, 'batch_size': 64, 'dropout': 0.5, 'hidden': 512}
# Grid Search Best Accuracy: 0.9932
# Grid Search Time: 2669.82 seconds
#
# Bayesian Search Best Config: {'conv_filters': np.float64(102.33736617440508), 'lr': np.float64(0.005598590859279775), 'batch_size': np.float64(214.7537845874586), 'dropout': np.float64(0.5142344384136116), 'hidden': np.float64(355.4871944430243)}
# Bayesian Search Best Accuracy: 0.9879
# Bayesian Search Time: 516.04 seconds
#
# Hyperband Best Config: {'conv_filters': 147, 'lr': 0.011312976753809767, 'batch_size': 256, 'dropout': 0.6772220821054592, 'hidden': 370}
# Hyperband Best Accuracy: 0.9814
# Hyperband Search Time: 211.88 seconds

# %% [markdown]
# ### Question

# %% [markdown]
# After running all three hyperparameter search methods, I observed that Grid Search achieved the highest accuracy (0.9932), but it also took the longest time to run - over 44 minutes (2669.82 seconds). This makes sense since Grid Search exhaustively evaluates all combinations, which ensures optimality but at the cost of time and computational resources.
#
# Bayesian Optimization, on the other hand, achieved slightly lower accuracy (0.9879) but completed in less than 9 minutes (516.04 seconds). It was much more efficient by intelligently exploring the search space rather than evaluating all possible combinations.
#
# Hyperband was the fastest, finishing in about 3.5 minutes (211.88 seconds), but its best accuracy (0.9814) was the lowest among the three. This tradeoff is expected, as Hyperband aggressively prunes poorly performing configurations early on to save time.
#
# Overall, the results highlight the classic trade-off between accuracy and search efficiency. If time and resources are not a constraint, Grid Search gives the best performance. However, for more practical scenarios, Bayesian Search provides a strong balance between performance and runtime, while Hyperband is ideal when speed is the top priority.
